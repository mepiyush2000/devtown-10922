# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn import datasets
cal_data = datasets.fetch_california_housing()

# %%
data = pd.DataFrame(cal_data.data, columns = cal_data.feature_names)
data["price"] = cal_data.target
data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  price
# ...

# %%
output = data["price"]
inputs = data.drop(["price"], axis = 1)

# %%
#split the data into train and test
from sklearn.model_selection import train_test_split
input_train, input_test, output_train, output_test = train_test_split(inputs, output, test_size = 0.2, random_state = 45)

# %%
## Applying three differnet models

# %%
from sklearn.linear_model import Ridge
rid = Ridge()
rid.fit(input_train, output_train)
# Out:
# Ridge()

# %%
from sklearn.tree import DecisionTreeRegressor
dtg = DecisionTreeRegressor()
dtg.fit(input_train, output_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
knn.fit(input_train, output_train)
# Out:
# KNeighborsRegressor()

# %%
## predicting from all models

# %%
pred_model1 = rid.predict(input_test)
pred_model2 = dtg.predict(input_test)
pred_model3 = knn.predict(input_test)

# %%
mse_model_1 = mean_squared_error(pred_model1, output_test) 
mse_model_2 = mean_squared_error(pred_model2, output_test) 
mse_model_3 = mean_squared_error(pred_model3, output_test) 

print("mse_model1: ", mse_model_1)
print("mse_model2: ", mse_model_2)
print("mse_model3: ", mse_model_3)
# Out:
# mse_model1:  0.5209527884475084
# mse_model2:  0.5398038770153827
# mse_model3:  1.1309081544872306

# %%
## Average ensemble prediction from 3 models
ensemsble_avg_pred = (pred_model1 + pred_model2 + pred_model3)/3

# %%
from sklearn.metrics import mean_squared_error, r2_score
print("mse_ensembeld_avg: ", mean_squared_error(ensemsble_avg_pred, output_test) )
# Out:
# mse_ensembeld_avg:  0.45400031298542987

# %%
#wieghted avg ensembele
